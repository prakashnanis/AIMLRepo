# %% [markdown]
# # Create a CNN model for binary class problems

# %%
C:\Users\Prakash Nani\OneDrive\AIMLRepo\Untitled Folder\dataset\test

# %%
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img,img_to_array,load_img
import matplotlib as mt
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Flatten

# %%
from keras.layers import Dropout

# %%
# Create an image instance of the ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    zoom_range=0.2,
    rescale=1./255,
    horizontal_flip=True,
    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 16
train_data = train_datagen.flow_from_directory('C:/Users/Prakash Nani/OneDrive/AIMLRepo/Untitled Folder/dataset/train',
                                               target_size=(150, 150),
                                               batch_size=batch_size,
                                               class_mode='binary')


test_data = test_datagen.flow_from_directory('C:/Users/Prakash Nani/OneDrive/AIMLRepo/Untitled Folder/dataset/test',
                                             target_size=(150, 150),
                                             batch_size=batch_size,
                                             class_mode='binary')
# Out:
# Found 840 images belonging to 2 classes.
# Found 188 images belonging to 2 classes.

# %%
model = Sequential()

# 1st convolution layer
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 2nd convolution layer
model.add(Conv2D(64, (3, 3),input_shape=(150,150,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 3rd convolution layer
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# Converting multi-dimensional to 1D array
model.add(Flatten())
model.add(Dense(units=150, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 32)        18464
#
#  max_pooling2d_2 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 9248)              0
#
#  dense (Dense)               (None, 150)               1387350
#
#  dropout (Dropout)           (None, 150)               0
#
#  dense_1 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 1425357 (5.44 MB)
# Trainable params: 1425357 (5.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
result=model.fit(train_data,
                 steps_per_epoch=48//batch_size,epochs=30,
                 validation_data=test_data,
                 validation_steps=48//batch_size)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 6s 2s/step - loss: 0.8991 - accuracy: 0.6042 - val_loss: 0.7764 - val_accuracy: 0.4792
# Epoch 2/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.7316 - accuracy: 0.5417 - val_loss: 0.6971 - val_accuracy: 0.5625
# Epoch 3/30
# 3/3 [==============================] - 5s 2s/step - loss: 0.6947 - accuracy: 0.4792 - val_loss: 0.6931 - val_accuracy: 0.5417
# Epoch 4/30
# 3/3 [==============================] - 4s 2s/step - loss: 0.6908 - accuracy: 0.5000 - val_loss: 0.6970 - val_accuracy: 0.4167
# Epoch 5/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.7151 - accuracy: 0.5208 - val_loss: 0.7193 - val_accuracy: 0.4167
# Epoch 6/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6937 - accuracy: 0.6250 - val_loss: 0.6965 - val_accuracy: 0.3958
# Epoch 7/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6954 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5208
# Epoch 8/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6935 - accuracy: 0.5000 - val_loss: 0.6924 - val_accuracy: 0.5208
# Epoch 9/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6903 - accuracy: 0.6250 - val_loss: 0.6880 - val_accuracy: 0.5417
# Epoch 10/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6939 - accuracy: 0.4792 - val_loss: 0.6840 - val_accuracy: 0.6250
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6809 - accuracy: 0.6042 - val_loss: 0.6818 - val_accuracy: 0.5625
# Epoch 12/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6986 - accuracy: 0.4792 - val_loss: 0.7234 - val_accuracy: 0.4167
# Epoch 13/30
# 3/3 [==============================] - 2s 944ms/step - loss: 0.7060 - accuracy: 0.4792 - val_loss: 0.6955 - val_accuracy: 0.4583
# Epoch 14/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6970 - accuracy: 0.5833 - val_loss: 0.6838 - val_accuracy: 0.6042
# Epoch 15/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6891 - accuracy: 0.6250 - val_loss: 0.6870 - val_accuracy: 0.6250
# Epoch 16/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6954 - accuracy: 0.3750 - val_loss: 0.6877 - val_accuracy: 0.6458
# Epoch 17/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6890 - accuracy: 0.6458 - val_loss: 0.6857 - val_accuracy: 0.6458
# Epoch 18/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.6925 - accuracy: 0.6042 - val_loss: 0.6870 - val_accuracy: 0.5417
# Epoch 19/30
# 3/3 [==============================] - 2s 908ms/step - loss: 0.6901 - accuracy: 0.5833 - val_loss: 0.6850 - val_accuracy: 0.6042
# Epoch 20/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6860 - accuracy: 0.5833 - val_loss: 0.6901 - val_accuracy: 0.5208
# Epoch 21/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6984 - accuracy: 0.5417 - val_loss: 0.7419 - val_accuracy: 0.3333
# Epoch 22/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6630 - accuracy: 0.6458 - val_loss: 0.6745 - val_accuracy: 0.6042
# Epoch 23/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6939 - accuracy: 0.5208 - val_loss: 0.7044 - val_accuracy: 0.4792
# Epoch 24/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6999 - accuracy: 0.5417 - val_loss: 0.6858 - val_accuracy: 0.6042
# Epoch 25/30
# 3/3 [==============================] - 2s 1s/step - loss: 0.7002 - accuracy: 0.5417 - val_loss: 0.6797 - val_accuracy: 0.6667
# Epoch 26/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6828 - accuracy: 0.6250 - val_loss: 0.6815 - val_accuracy: 0.6458
# Epoch 27/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6929 - accuracy: 0.4792 - val_loss: 0.6813 - val_accuracy: 0.6250
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6922 - accuracy: 0.5000 - val_loss: 0.6748 - val_accuracy: 0.6250
# Epoch 29/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6755 - accuracy: 0.5417 - val_loss: 0.6894 - val_accuracy: 0.5417
# Epoch 30/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6768 - accuracy: 0.4792 - val_loss: 0.6717 - val_accuracy: 0.6042

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(result.history.keys())
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('Model Accuracy- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['Train','Test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model Loss- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['Train','Test'])
plt.show()

# %% [markdown]
# # Build a multiclass classification model using CNN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPool2D
from keras import backend as k

# %%
batch_size=128
num_classes=10
epochs=12

# %%
img_rows,img_cols=32,32

# %%
from keras.datasets import cifar100
(xtrain,ytrain),(xtest,ytest)=cifar100.load_data()

# %%
print('Training set images shape: {}'.format(xtrain.shape))
print('Testing set images shape: {}'.format(xtest.shape))

print('Training set labels shape: {}'.format(ytrain.shape))
print('Testing set labels shape: {}'.format(ytest.shape))
# Out:
# Training set images shape: (50000, 32, 32, 3)
# Testing set images shape: (10000, 32, 32, 3)
# Training set labels shape: (50000, 1)
# Testing set labels shape: (10000, 1)

# %%
import matplotlib.pyplot as plt

plt.imshow(xtrain[3])

# %%
xtrain[0].shape
# Out:
# (32, 32, 3)

# %%
xtrain=xtrain.reshape(xtrain.shape[0],img_rows,img_cols,3)
xtest=xtest.reshape(xtest.shape[0],img_rows,img_cols,3)

print(xtrain.shape)
print(xtest.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
xtrain=xtrain.astype('float32')
xtest=xtest.astype('float32')

# %%
xtrain/=255
xtest/=255

# %%
print('xtrain shape:',xtrain.shape)
print(xtrain.shape[0],'train samples')
print(xtest.shape[0],'test samples')
# Out:
# xtrain shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
ytrain=keras.utils.to_categorical(ytrain)
ytest=keras.utils.to_categorical(ytest)

# %%
model=Sequential()

#add model layers
model.add(Conv2D(64,kernel_size=3,activation='relu',input_shape=(32,32,3)))
model.add(Dropout(0.2))

model.add(Conv2D(32,kernel_size=3,activation='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

#output layer
model.add(Dense(100,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 30, 30, 64)        1792
#
#  dropout_4 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 32)        18464
#
#  max_pooling2d_6 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 6272)              0
#
#  dense_5 (Dense)             (None, 100)               627300
#
# =================================================================
# Total params: 647556 (2.47 MB)
# Trainable params: 647556 (2.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
result=model.fit(xtrain,ytrain,batch_size=batch_size,
                epochs=3,verbose=1,
                validation_data=(xtest,ytest))
# Out:
# Epoch 1/3
# 391/391 [==============================] - 194s 493ms/step - loss: 3.7071 - accuracy: 0.1529 - val_loss: 3.2854 - val_accuracy: 0.2316
# Epoch 2/3
# 391/391 [==============================] - 186s 476ms/step - loss: 3.0231 - accuracy: 0.2774 - val_loss: 2.9896 - val_accuracy: 0.2907
# Epoch 3/3
# 391/391 [==============================] - 186s 476ms/step - loss: 2.6255 - accuracy: 0.3568 - val_loss: 2.8525 - val_accuracy: 0.3160

# %%
score=model.evaluate(xtest,ytest,verbose=0)
print('Test Loss:',score[0])
print()
print('Test accuracy',score[1])
# Out:
# Test Loss: 2.852536678314209
#
# Test accuracy 0.3160000145435333

# %%
import matplotlib.pyplot as plt
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(16,5))

ax1.plot(result.history['accuracy'])
ax1.plot(result.history['val_accuracy'])

ax1.set_title('Model Performance')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epochs')
ax1.legend(['Train','Test'])


ax2.plot(result.history['loss'])
ax2.plot(result.history['val_loss'])

ax2.set_title('Model Performance')
ax2.set_ylabel('loss')
ax2.set_xlabel('epochs')
ax2.legend(['Train','Test'])
